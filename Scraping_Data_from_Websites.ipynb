# %%
import bs4 as bs
import urllib.request

# %%
src = urllib.request.urlopen('https://www.nytimes.com/').read()

# %%
#bsoup = bs.BeautifulSoup(src, 'lxml')

bsoup = bs.BeautifulSoup(src)

# %%
print(bsoup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <title data-rh="true">The New York Times - Breaking News, World News &amp; Multimedia</title>
# <meta content="en-US" data-rh="true" itemprop="inLanguage"/><meta content="noarchive,noodp,noydir" data-rh="true" name="robots"/><meta content="The New York Times" data-rh="true" name="application-name"/><meta content="https://www.nytimes.com" data-rh="true" name="msapplication-starturl"/><meta content="name=Search;action-uri=https://www.nytimes.com/search/?src=iepin;icon-uri=https://static01.nyt.com/images/icons/search.ico" data-rh="true" name="msapplication-task"/><meta content="name=Most Popular;action-uri=https://www.nytimes.com/gst/mostpopular.html?src=iepin;icon-uri=https://static01.nyt.com/images/icons/mostpopular.ico" data-rh="true" name="msapplication-task"/><meta content="name=Video;action-uri=https://video.nytimes.com/?src=iepin;icon-uri=https://static01.nyt.com/images/icons/video.ico" data-rh="true" name="msapplication-task"/><meta content="name=Homepage;action-uri=https://www.nytimes.com?src=iepin&amp;adxnnl=1;icon-uri=https://static01.nyt.com/images/icons/homepage.ico" data-rh="true" name="msapplication-task"/><meta content="The New York Times: Find breaking news, multimedia, reviews &amp; opinion on Washington, business, sports, movies, travel, books, jobs, education, real estate, cars &amp; more at nytimes.com." data-rh="true" name="description"/><meta content="https://www.nytimes.com" data-rh="true" property="og:url"/><meta content="website" data-rh="true" property="og:type"/><meta content="Breaking News, World News &amp; Multimedia" data-rh="true" property="og:title"/><meta content="The New York Times: Find breaking news, multimedia, reviews &amp; opinion on Washington, business, sports, movies, travel, books, jobs, education, real estate, cars &amp; more at nytimes.com." data-rh="true" property="og:description"/><meta content="https://static01.nyt.com/newsgraphics/images/icons/defaultPromoCrop.png" data-rh="true" property="og:image"/><meta content="Homepage" data-rh="true" name="CG"/><meta content="" data-rh="true" name="SCG"/><meta content="Homepage" data-rh="true" name="PT"/><meta content="" data-rh="true" name="PST"/><meta content="Coronavirus;COVID-19,Funerals,Rural area,Hospital,Georgia,Nursing home,Old age;elderly;senior citizens,CDC,Centers for Medicare and Medicaid Services,Delivery Services,Strikes Labor,Jobs,,Instacart,Amazon,Trader Joe's,Whole Foods,Staten Island,Supermarkets,Retail,Border Wall, Border Fence,Governors,Doug Ducey,Ajo AZ,Politics,Government Surveillance,War and Emergency Powers,Civil Rights,Freedom of speech,Benjamin Netanyahu,Viktor Orban,Israel,Hungary,Great Britain,China,Ren Zhiqiang,Censorship,Social Media,Epidemic;Pandemic,Communist Party of China,North Korea,Kim Jong-un,Humanitarian aid,Red Cross,Daily NK,Kim Seung-eun,Joe Biden,Campaign finance,Computers and the Internet,Tech Industry,2020 Election,Donald Trump,PACs,Campaign advertising,Democrats,Primaries,DNC,US Politics,Online advertising,Andrew Cuomo,New York,Gabriel Matzneff,Child Abuse,Rape,France,Publishing,Writer,Women and Girls,Vanessa Springora" data-rh="true" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="9869919170" property="fb:app_id"/>
# <meta name="twitter:site" value="@nytimes"/>
# <link data-rh="true" href="/vi-assets/static-assets/favicon-4bf96cb6a1093748bf5b3c429accb9b4.ico" rel="shortcut icon"/><link data-rh="true" href="/vi-assets/static-assets/apple-touch-icon-319373aaf4524d94d38aa599c56b8655.png" rel="apple-touch-icon"/><link data-rh="true" href="/vi-assets/static-assets/ios-ipad-144x144-319373aaf4524d94d38aa599c56b8655.png" rel="apple-touch-icon-precomposed" sizes="144×144"/><link data-rh="true" href="/vi-assets/static-assets/ios-iphone-114x144-61d373c43aa8365d3940c5f1135f4597.png" rel="apple-touch-icon-precomposed" sizes="114×114"/><link data-rh="true" href="/vi-assets/static-assets/ios-default-homescreen-57x57-7cccbfb151c7db793e92ea58c30b9e72.png" rel="apple-touch-icon-precomposed"/><link data-rh="true" href="https://www.nytimes.com" rel="canonical"/><link data-rh="true" href="https://rss.nytimes.com/services/xml/rss/nyt/HomePage.xml" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="https://g1.nyt.com/fonts/css/web-fonts.5810def60210a2fa7d0848f37e3fa048bb6147b1.css" rel="stylesheet" type="text/css"/>
# <link href="/vi-assets/static-assets/global-f2dfe2d3172b0c4bd44703c796af9242.css" rel="stylesheet"/>
# <style>[data-timezone] { display: none }</style>
css-8pe5zk{display:none;text-align:center;}@media (min-width:1024px){.css-8pe5zk{display:block;}}.css-5wt1bj{color:#666;-webkit-letter-spacing:0.03em;-moz-letter-spacing:0.03em;-ms-letter-spacing:0.03em;letter-spacing:0.03em;margin-top:2px;}.css-1vlye70{display:inline-block;font-family:nyt-franklin,helvetica,arial,sans-serif;font-size:10px;text-transform:uppercase;color:#000;font-weight:500;}.css-1vlye70:first-child{margin-left:0;}.css-ogiugu{display:inline-block;border-radius:3px;padding:7px 10px;}.css-ogiugu:hover{background-color:#f7f7f7;}@media (min-width:1024px){.css-ogiugu{padding:7px 8px 6px;-webkit-transition:background 0.6s ease;transition:background 0.6s ease;}}.css-1gz70xg{border-left:1px solid #ccc;color:#326891;height:12px;margin-left:8px;padding-left:8px;}.css-9e9ivx{display:none;fo ...
# <script type="text/javascript">
#       // 21.394000000000002kB
#       window.viHeadScriptSize = 21.394000000000002;
#       window.NYTD = {};
#       (function () { var _f=function(e){window.vi=window.vi||{},window.vi.env=Object.freeze(e)};;_f.apply(null, [{"JKIDD_PATH":"https://a.nytimes.com/svc/nyt/data-layer","ET2_URL":"https://a.et.nytimes.com","WEDDINGS_PATH":"https://content.api.nytimes.com","GDPR_PATH":"https://us-central1-nyt-dsra-prd.cloudfunctions.net/datagov-dsr-felix","RECAPTCHA_SITEKEY":"6LevSGcUAAAAAF-7fVZF05VTRiXvBDAY4vBSPaTF","ABRA_ET_URL":"//et.nytimes.com","NODE_ENV":"production","SENTRY_SAMPLE_RATE":"10","EXPERIMENTAL_ROUTE_PREFIX":"","ENVIRONMENT":"prd","RELEASE":"702c9269ea45b6708427fed796218cefe33d93e2","AUTH_HOST":"https://myaccount.nytimes.com","SWG_PUBLICATION_ID":"nytimes.com","GQL_FETCH_TIMEOUT":"4000","GOOGLE_CLIENT_ID":"1005640118348-amh5tgkq641oru4fbhr3psm3gt2tcc94.apps.googleusercontent.com","STORY_SURROGATE_CONTROL":"max-age=300, stale-if-error=259200, stale-while-revalidate=259200"}]); })();;
#     !function(){if('PerformanceLongTaskTiming' in window){var g=window.__tti={e:[]};
#     g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});
#     g.o.observe({entryTypes:['longtask']})}}();
# ;
# 	!function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);
# ;
#
# try {
#   var observer = new window.PerformanceObserver(function(list) {
#     var entries = list.getEntries();
#     for (var i = 0; i < entries.length; i += 1) {
#       var entry = entries[i];
#       var performance = {};
#
#       performance[entry.name] = Math.round(entry.startTime + entry.duration);
#       (window.dataLayer = window.dataLayer || []).push({
#         event: "performance",
#         pageview: {
#           performance: performance,
#         },
#       });
#     }
#   });
#   observer.observe({ entryTypes: ["paint"] });
# } catch (e) {}
# ;
# !function(i,e){var a,s,c,p,u,g=[],
# l="object"==typeof i.navigator&&"string"==typeof i.navigator.userAgent&&/iP(ad|hone|od)/.test(
# i.navigator.userAgent),f="object"==typeof i.navigator&&i.navigator.sendBeacon,
# y=f?l?"xhr_ios":"beacon":"xhr";function d(){var e,t,n=i.crypto||i.msCrypto;if(n)t=n.getRandomValues(
# new Uint8Array(18));else for(t=[];t.length<18;)t.push(256*Math.random()^255&(e=e||+new Date)),
# e=Math.floor(e/256);return btoa(String.fromCharCode.apply(String,t)).replace(/\+/g,"-").replace(
# /\//g,"_")}if(i.nyt_et)try{console.warn("et2 snippet should only load once per page")}catch(e
# ){}else i.nyt_et=function(){var e,t,n,o=arguments;function r(r){g.length&&(function(e,t,n){if(
# "beacon"===y||f&&r)return i.navigator.sendBeacon(e,t)
# ;var o="undefined"!=typeof XMLHttpRequest?new XMLHttpRequest:new ActiveXObject("Microsoft.XMLHTTP")
# ;o.open("POST",e),o.withCredentials=!0,o.setRequestHeader("Accept","*/*"),
# "string"==typeof t?o.setRequestHeader("Content-Type","text/plain;charset=UTF-8"
# ):"[object Blob]"==={}.toString.call(t)&&t.type&&o.setRequestHeader("Content-Type",t.type);try{
# o.send(t)}catch(e){}}(a+"/track",JSON.stringify(g)),g.length=0,clearTimeout(u),u=null)}if(
# "string"==typeof o[0]&&/init/.test(o[0])&&(c=d(),"init"==o[0]&&!s)){if(s=d(),
# "string"!=typeof o[1]||!/^http/.test(o[1]))throw new Error("init must include an et host url")
# ;a=String(o[1]).replace(/\/$/,""),"string"==typeof o[2]&&(p=o[2])}n="page_exit"==(e=o[o.length-1]
# ).subject||"ob_click"==(e.eventData||{}).type,a&&"object"==typeof e&&(
# t="page"==e.subject||"page_soft"==e.subject?c:d(),e.sourceApp&&(p=e.sourceApp),e.sourceApp=p,g.push(
# {context_id:s,pageview_id:c,event_id:t,client_lib:"v1.0.6",sourceApp:p,how:n&&l&&f?"beacon_ios":y,
# client_ts:+new Date,data:JSON.parse(JSON.stringify(e))}),"send"==o[0]||t==c||n?r(n):u||(
# u=setTimeout(r,5500)))},i.nyt_et.get_pageview_id=function(){return c}}(window);
# ;!function(r){var n,t;r=r||self,n=r.Abra,(t=r.Abra=function(){"use strict";var r=Array.isArray,n=function(r,n,t){return r(t,n).reduce((function(r,n){return parseFloat(r)+parseFloat(n)}),0)},t=function(r,n,t){var e=r(t,n);return e[0]/e[1]},e=function(r,n,t){var e=r(t,n);return e[0]%e[1]},u=function(r,n,t){return r(t,n).reduce((function(r,n){return parseFloat(r)*parseFloat(n)}),1)},o=function(r,n,t){var e=r(t,n),u=e[0],o=e[1];return void 0===o?-u:u-o};function i(n){return!(r(n)&&0===n.length||!n)}var a=function(r,n,t){for(var e,u=0;u<t.length;u++)if(!i(e=r(t[u],n)))return e;return e},f=function(r,n,t){var e;for(e=0;e<t.length-1;e+=2)if(i(r(t[e],n)))return r(t[e+1],n);return t.length===e+1?r(t[e],n):null},c=function(r,n,t){return!i(r(t,n)[0])},l=function(r,n,t){for(var e,u=0;u<t.length;u++)if(i(e=r(t[u],n)))return e;return e},v=function(r,n,t){var e=r(t,n);return e[0]===e[1]},s=function(r,n,t){var e=r(t,n);return e[0]!==e[1]},d=function(r,n,t){var e=r(t,n),u=e[0],o=e[1];return!(!o||void 0===o.indexOf)&&-1!==o.indexOf(u)},h=function(r,n,t){var e=r(t,n);return e[0]>e[1]},g=function(r,n,t){var e=r(t,n);return e[0]>=e[1]},p=function(r,n,t){var e=r(t,n),u=e[0],o=e[1],i=e[2];return void 0===i?u<o:u<o&&o<i},b=function(r,n,t){var e=r(t,n),u=e[0],o=e[1],i=e[2];return void 0===i?u<=o:u<=o&&o<=i},w=function(r,n,t){var e=t[0],u=t[1],o=t.slice(2),i=r(e,n);if(!i)return null;if(0===o.length)return null;if(1===o.length)return r(o[0],n);if(4294967295===o[0])return r(o[1],n);for(var a=function(r){var n,t,e,u,o,i=[],a=[t=1732584193,e=4023233417,~t,~e,3285377520],f=[],c=unescape(encodeURI(r))+"",l=c.length;for(f[r=--l/4+2|15]=8*l;~l;)f[l>>2]|=c.charCodeAt(l)<<8*~l--;for(n=l=0;n<r;n+=16){for(t=a;l<80;t=[t[4]+(i[l]=l<16?~~f[n+l]:2*c|c<0)+1518500249+[e&u|~e&o,c=341275144+(e^u^o),882459459+(e&u|e&o|u&o),c+1535694389][l++/5>>2]+((c=t[0])<<5|c>>>27),c,e<<30|e>>>2,u,o])c=i[l-3]^i[l-8]^i[l-14]^i[l-16],e=t[1],u=t[2],o=t[3];for(l=5;l;)a[--l]+=t[l]}return a[0]>>>0}(i+" "+r(u,n));o.length>1;){var f=o.splice(0,2),c=f[0],l=f[1];if(a<=r(c,n))return r(l,n)}return 0===o.length?null:r(o[0],n)},m=function(r,n,t){var e=t[0],u=t[1],o=r(e,n);return null==o?null:new RegExp(u).test(o)},y=function(r,n,t){var e=r(t,n),u=e[0],o=e[1];if(!u)return n;for(var i=n,a=String(u).split("."),f=0;f<a.length&&(i=i[a[f]]);f++);if(null==i){if(!o){var c=new Error("Abra missing input: "+u);throw c.missingInput=u,c}i=o}return null!=i?i:null};return function(i,k,A,O){void 0===i&&(i={}),void 0===k&&(k={}),void 0===A&&(A={}),void 0===O&&(O=!1);var j=function(){var r={},n=function(n){if(n)for(var t,e=decodeURIComponent(n[1]),u=/(?:^|,)([^,=]+)=([^,]+)/g;t=u.exec(e);){var o=t,i=o[1],a=o[2];r[i]=a}};n(document.cookie.match(/(?:^|;) *abra-overrides=([^;]+)/)),n(window.location.search.match(/(?:\?|&)abra-overrides=([^&]+)/));var t=/(?:^|;) *abra-nuke=true(?:;|$)/.test(document.cookie)||/(?:\?|&)abra-nuke=true(?:&|$)/.test(window.location.search);return[r,t]}(),x=j[0],E=j[1];Object.keys(A).forEach((function(r){x[r]=A[r]}));var F,C=O||E,I=(F={var:y,if:f,"===":v,"!==":s,and:a,or:l,"!":c,">":h,">=":g,"<":p,"<=":b,"+":n,"-":o,"*":u,"/":t,"%":e,in:d,abtest_partition:w,regex_match:m,ref:function(r,n,t){var e=r(t,n)[0];return R(e)}},function n(t,e){if(e||(e={}),r(t))return t.map((function(r){return n(r,e)}));if(!function(n){return"object"==typeof n&&null!==n&&!r(n)&&1===Object.keys(n).length}(t))return t;var u=function(r){return Object.keys(r)[0]}(t),o=t[u];r(o)||(o=[o]);var i=F[u];if(!i)throw new Error("Unrecognized operation "+u);return i(n,e,o)}),R=function(r){if(!r)return null;var n=x[r];if(void 0===n){if(!C){if(Object.prototype.hasOwnProperty.call(x,r))throw new Error("circular logic");x[r]=void 0,n=I(i[r],k)}void 0===n&&(n=null),x[r]=n}return n};return R}}()).noConflict=function(){return r.Abra=n,t}}(this);
# ;(function () { var NYTD="undefined"!=typeof window&&window.NYTD?window.NYTD:{};function setupTimeZone(){var e='[data-timezone][data-timezone~="'+(new Date).getHours()+'"] { display: block }',t=document.createElement("style");t.innerHTML=e,document.head.appendChild(t)}function addNYTAppClass(){var e=window.navigator.userAgent||window.navigator.vendor||window.opera,t=-1!==e.indexOf("nyt_android"),n=-1!==e.indexOf("nytios");(t||n)&&document.documentElement.classList.add("NYTApp")}function setupPageViewId(){NYTD.PageViewId={},NYTD.PageViewId.update=function(){return"undefined"!=typeof nyt_et&&"function"==typeof window.nyt_et.get_pageview_id?(window.nyt_et("pageinit"),NYTD.PageViewId.current=window.nyt_et.get_pageview_id()):NYTD.PageViewId.current="xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx".replace(/[xy]/g,function(e){var t=16*Math.random()|0;return("x"===e?t:3&t|8).toString(16)}),NYTD.PageViewId.current}}var _f=function(){try{document.domain="nytimes.com"}catch(e){}window.swgUserInfoXhrObject=new XMLHttpRequest,setupPageViewId(),setupTimeZone(),addNYTAppClass(),window.nyt_et&&"function"==typeof window.nyt_et&&window.nyt_et("init",vi.env.ET2_URL,"nyt-vi",{subject:"page",canonicalUrl:(document.querySelector("link[rel=canonical]")||{}).href,articleId:(document.querySelector("meta[name=articleid]")||{}).content,nyt_uri:(document.querySelector("meta[name=nyt_uri]")||{}).content,pubpEventId:(document.querySelector("meta[name=pubp_event_id]")||{}).content,url:location.href,referrer:document.referrer||void 0,client_tz_offset:(new Date).getTimezoneOffset()}),"undefined"!=typeof nyt_et&&"function"==typeof window.nyt_et.get_pageview_id?NYTD.PageViewId.current=window.nyt_et.get_pageview_id():NYTD.PageViewId.update()};;_f.apply(null, []); })();;(function () { var NYTD="undefined"!=typeof window&&window.NYTD?window.NYTD:{};var _f=function(a){window.Abra&&"function"==typeof window.Abra&&(NYTD.Abra=function(t){var r=(t.document.cookie.match(/(?:^|;) *nyt-a=([^;]*)/)||[])[1],e=[];function n(a){return n.getAbraSync(a).variant}return t.dataLayer=t.dataLayer||[],n.config=a.abraConfig||{},n.reportedAllocations={},n.reportedExposures={},n.getAbraSync=function(a){var e=null,o=!1;try{e=t.Abra(n.config,{agent_id:r})(a),o=!0}catch(a){}return{variant:e,allocated:o}},n.reportExposure=function(a){var r=n.getAbraSync(a).variant;void 0!==n.reportedExposures[a]&&r===n.reportedExposures[a]||(n.reportedExposures[a]=r,t.dataLayer.push({event:"ab-expose",abtest:{test:a,variant:r||"0"}}))},Object.keys(n.config).forEach(function(a){var t=n.getAbraSync(a);t.allocated&&(n.reportedAllocations[a]=t.variant,e.push({test:a,variant:t.variant}))}),t.dataLayer.push({event:"ab-alloc",abtest:{batch:e}}),n}(this))};;_f.apply(null, [{"abraConfig":{"dfp_adslot4v2":{"abtest_partition":[{"var":"agent_id"},"dfp_adslot4v2",4294967295,"1_external"]},"DFP_als_home":{"abtest_partition":[{"var":"agent_id"},"DFP_als_home",4294967295,"1_als"]},"DFP_als":{"abtest_partition":[{"var":"agent_id"},"DFP_als",4294967295,"1_als"]},"DFP_amzn":{"abtest_partition":[{"var":"agent_id"},"DFP_amzn",42949672,"0_control",429496729,"0_control",472446402,"1_amzn_fast_fetch",515396075,"2_adslot_priority",901943131,"2_adslot_priority",944892804,"3_no_mnet"]},"dfp_messaging_flexframe_ctr":{"abtest_partition":[{"var":"agent_id"},"dfp_messaging_flexframe_ctr",322122546,"2_noheadnosummary",644245093,"1_msgInv_noCTA",4294967295,"0_control"]},"HOME_timesExclusive":{"abtest_partition":[{"var":"agent_id"},"HOME_timesExclusive",2147483647,"0_control",4294967295,"1_variant"]},"INBOX_individualpage_redesign":{"abtest_partition":[{"var":"agent_id"},"INBOX_individualpage_redesign",4294967295,"0_control"]},"MAPS_fr_interests_block":{"abtest_partition":[{"var":"agent_id"},"MAPS_fr_interests_block"]},"MC_bar1_color_0120":{"if":[{"and":[{"in":[{"var":"geo_country"},["US"]]},{"===":[{"var":"device_type"},"desktop"]},{"!==":[{"var":"user_type"},"anon"]}]},{"abtest_partition":[{"var":"agent_id"},"MC_bar1_color_0120",429496729,"1_black_ ...
#     </script>
# <script>!function(e){function t(t){for(var n,a,i=t[0],l=t[1],f=t[2],c=0,s=[];c<i.length;c++)a=i[c],Object.prototype.hasOwnProperty.call(o,a)&&o[a]&&s.push(o[a][0]),o[a]=0;for(n in l)Object.prototype.hasOwnProperty.call(l,n)&&(e[n]=l[n]);for(p&&p(t);s.length;)s.shift()();return u.push.apply(u,f||[]),r()}function r(){for(var e,t=0;t<u.length;t++){for(var r=u[t],n=!0,i=1;i<r.length;i++){var l=r[i];0!==o[l]&&(n=!1)}n&&(u.splice(t--,1),e=a(a.s=r[0]))}return e}var n={},o={50:0},u=[];function a(t){if(n[t])return n[t].exports;var r=n[t]={i:t,l:!1,exports:{}};return e[t].call(r.exports,r,r.exports,a),r.l=!0,r.exports}a.m=e,a.c=n,a.d=function(e,t,r){a.o(e,t)||Object.defineProperty(e,t,{enumerable:!0,get:r})},a.r=function(e){"undefined"!=typeof Symbol&&Symbol.toStringTag&&Object.defineProperty(e,Symbol.toStringTag,{value:"Module"}),Object.defineProperty(e,"__esModule",{value:!0})},a.t=function(e,t){if(1&t&&(e=a(e)),8&t)return e;if(4&t&&"object"==typeof e&&e&&e.__esModule)return e;var r=Object.create(null);if(a.r(r),Object.defineProperty(r,"default",{enumerable:!0,value:e}),2&t&&"string"!=typeof e)for(var n in e)a.d(r,n,function(t){return e[t]}.bind(null,n));return r},a.n=function(e){var t=e&&e.__esModule?function(){return e.default}:function(){return e};return a.d(t,"a",t),t},a.o=function(e,t){return Object.prototype.hasOwnProperty.call(e,t)},a.p="/vi-assets/static-assets/";var i=window.webpackJsonp=window.webpackJsonp||[],l=i.push.bind(i);i.push=t,i=i.slice();for(var f=0;f<i.length;f++)t(i[f]);var p=l;r()}([]);
# //# sourceMappingURL=runtime~adslot-f885ed7934fb0099e201.js.map</script>
# <script async="" src="/vi-assets/static-assets/adslot-62ac0f8ce48e20d31a57.js"></script>
# <script data-rh="true" type="application/ld+json">{"@context":"http://schema.org","@type":"WebPage","image":[{"@context":"http://schema.org","@type":"ImageObject","url":"https://static01.nyt.com/vi-assets/images/share/1200x675_nameplate.png","height":675,"width":1200},{"@context":"http://schema.org","@type":"ImageObject","url":"https://static01.nyt.com/vi-assets/images/share/1200x900_t.png","height":900,"width":1200},{"@context":"http://schema.org","@type":"ImageObject","url":"https://static01.nyt.com/vi-assets/images/share/1200x1200_t.png","height":1200,"width":1200}],"name":"The New York Times","mainEntity":{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/world/coronavirus-news.html","position":1},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/us/politics/trump-governors-coronavirus-testing.html","position":2},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/business/stock-market-today-coronavirus.html","position":3},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/us/politics/trump-coronavirus.html","position":4},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/us/politics/trump-women-coronavirus.html","position":5},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/health/coronavirus-restrictions-fevers.html","position":6},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/news-event/coronavirus","position":7},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/us/coronavirus-funeral-albany-georgia.html","position":8},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/nyregion/coronavirus-nursing-homes-nyc.html","position":9},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/business/economy/coronavirus-instacart-amazon.html","position":10},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/us/coronavirus-border-wall-arizona.html","position":11},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/spotlight/at-home","position":12},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/world/europe/coronavirus-governments-power.html","position":13},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/business/china-ren-zhiqiang-censorship.html","position":14},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/world/asia/north-korea-coronavirus.html","position":15},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/us/politics/biden-trump-campaign-fundraising.html","position":16},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/us/politics/andrew-cuomo.html","position":17},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/world/europe/gabriel-matzneff-victim-france.html","position":18},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/opinion/new-york-budget-covid.html","position":19},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/opinion/coronavirus-n95-mask.html","position":20},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/31/opinion/coronavirus-trump-cuomo-biden.html","position":21},{"@context":"http://schema.org","@type":"ListItem","url":"https://www.nytimes.com/2020/03/30/opinion/coronavirus-test-cost-bill.html","position":22},{"@context":"http://schema.org","@type":"ListItem","url":"https://ww ...
#   if (typeof testCookie === 'undefined') {
#     var testCookie = function (name) {
#       var match = document.cookie.match(new RegExp(name + '=([^;]+)'));
#       if (match) return match[1];
#     }
#   }
# </script><script data-rh="true">if (window.NYTD.Abra('dfp_home_toggle') !== '1_block') {
#
#   function placeGpt() {
#     var purrCookie = testCookie('nyt-purr');
#     if (purrCookie && purrCookie.substring(4, 5) === 's' ||
#         purrCookie && purrCookie.substring(4, 5) === 'a'
#     ) return;
#     var gptScript = document.createElement('script');
#     gptScript.async = 'async';
#     gptScript.src = '//securepubads.g.doubleclick.net/tag/js/gpt.js';
#     document.head.appendChild(gptScript);
#   }
#   placeGpt();
#
#   }</script><script data-rh="true">if (window.NYTD.Abra('dfp_home_toggle') !== '1_block') {
#
#   var purrCookie = testCookie('nyt-purr');
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#
#   if (purrCookie && purrCookie.substring(4, 5) === 'n') {
#     googletag.cmd.push(function() {
#       googletag.pubads().setRequestNonPersonalizedAds(1);
#     });
#   }
#   }</script><script data-rh="true">if (window.NYTD.Abra('dfp_home_toggle') !== '1_block') {
#     (function () { var _f=function(){var t,e,o=50,n=50;function i(t){if(!document.getElementById("3pCheckIframeId")){if(t||(t=1),!document.body){if(t>o)return;return t+=1,setTimeout(i.bind(null,t),n)}var e,a,r;e="https://static01.nyt.com/ads/tpc-check.html",a=document.body,(r=document.createElement("iframe")).src=e,r.id="3pCheckIframeId",r.style="display:none;",r.height=0,r.width=0,a.insertBefore(r,a.firstChild)}}function a(t){if("https://static01.nyt.com"===t.origin)try{"3PCookieSupported"===t.data&&googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","true")}),"3PCookieNotSupported"===t.data&&googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","false")})}catch(t){}}function r(){if(function(){if(Object.prototype.toString.call(window.HTMLElement).indexOf("Constructor")>0)return!0;if("[object SafariRemoteNotification]"===(!window.safari||safari.pushNotification).toString())return!0;try{return window.localStorage&&/Safari/.test(window.navigator.userAgent)}catch(t){return!1}}()){try{window.openDatabase(null,null,null,null)}catch(e){return t(),!0}try{localStorage.length?e():(localStorage.x=1,localStorage.removeItem("x"),e())}catch(o){navigator.cookieEnabled?t():e()}return!0}}!function(){try{googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","unknown")})}catch(t){}}(),t=function(){try{googletag.cmd.push(function(){googletag.pubads().setTargeting("cookie","private")})}catch(t){}}||function(){},e=function(){window.addEventListener("message",a,!1),i(0)}||function(){},function(){if(window.webkitRequestFileSystem)return window.webkitRequestFileSystem(window.TEMPORARY,1,e,t),!0}()||r()||function(){if(!window.indexedDB&&(window.PointerEvent||window.MSPointerEvent))return t(),!0}()||e()};;_f.apply(null, []); })();
#   }</script><script data-rh="true" id="als-svc">if (window.NYTD.Abra('DFP_als') !== '2_block') {
#     (function () { var _f=function(e){let t=()=>{var e=new Date,t=e.getFullYear();return e.getMonth()<9&&(t+="0"),t+=e.getMonth()+1,e.getDate()<10&&(t+="0"),t+=e.getDate(),e.getHours()<10&&(t+="0"),t+=e.getHours(),e.getMinutes()<10&&(t+="0"),t+=e.getMinutes(),e.getSeconds()<10&&(t+="0"),t+e.getSeconds()};window.googletag=window.googletag||{},googletag.cmd=googletag.cmd||[];var n,a=new XMLHttpRequest,o="prd"===window.vi.env.ENVIRONMENT?"als-svc.nytimes.com":"als-svc.dev.nytimes.com",i=document.querySelector('[name="nyt_uri"]');if("/"===location.pathname){var l=encodeURIComponent("https://www.nytimes.com/pages/index.html");n="uri="+l}else if(void 0===i||""===i||null===i){var s=e||location.protocol+"//"+location.hostname+location.pathname;n="url="+encodeURIComponent(s)}else{l=encodeURIComponent(i.content);n="uri="+l}var r=document.querySelector('[name="template"]'),d=document.querySelector('[name="prop"]'),g=document.querySelector('[name="plat"]'),c=null==r||null==r.content?"":r.content,u=null==d||null==d.content?"nyt":d.content,m=null==g||null==g.content?"web":g.content;window.innerWidth<740&&(u="mnyt",m="mweb");var w=window.localStorage.getItem("als_test_clientside");window.googletag.cmd.push(function(){w&&0!==w.length?googletag.pubads().setTargeting("als_test_clientside",w):googletag.pubads().setTargeting("als_test_clientside","empty_empty_empty_empty_empty_"+t())});let p=window.localStorage.getItem("mktg");p&&window.googletag.cmd.push(function(){googletag.pubads().setTargeting("mktg",p)});let _=window.localStorage.getItem("bt");_&&window.googletag.cmd.push(function(){googletag.pubads().setTargeting("bt",_)});let b=window.localStorage.getItem("sub");b&&window.googletag.cmd.push(function(){googletag.pubads().setTargeting("sub",b)}),a.open("GET","https://"+o+"/als?"+n+"&typ="+c+"&prop="+u+"&plat="+m,!0),a.withCredentials=!0,a.send(),a.onerror=function(){var e="reqfailed_reqfailed_reqfailed_reqfailed_reqfailed_"+t();window.googletag.cmd.push(function(){googletag.pubads().setTargeting("als_test_clientside",e)});var a={event:"impression",module:{name:"alice-timing",context:"script-load",label:"alice-error-reqfail-"+n}};(window.dataLayer=window.dataLayer||[]).push(a)},a.onreadystatechange=function(){if(4===a.readyState)if(200===a.status){var e=new Date,o=JSON.parse(a.responseText);window.googletag.cmd.push(function(){if(o.als_test_clientside&&0!==o.als_test_clientside.length){let t=(new Date).getTime()-e.getTime()+"_server_server_server_server_20200326152254";googletag.pubads().setTargeting("als_test_clientside",t),window.localStorage.setItem("als_test_clientside","ls-"+o.als_test_clientside)}else{var n=void 0===o.als_test_clientside?"undefined_undefined_undefined_undefined_undefined_"+t():"blank_blank_blank_blank_blank_"+t();googletag.pubads().setTargeting("als_test_clientside",n);var a={event:"impression",module:{name:"alice-timing",context:"script-load",label:"alice-error-test-client-undefined"}};(window.dataLayer=window.dataLayer||[]).push(a)}if(void 0!==o.User){if(void 0!==o.User.mktg)googletag.pubads().setTargeting("mktg",o.User.mktg),window.localStorage.setItem("mktg",o.User.mktg);else{a={event:"impression",module:{name:"alice-timing",context:"script-load",label:"alice-error-mktg-undefined"}};(window.dataLayer=window.dataLayer||[]).push(a)}if(void 0!==o.User.bt)googletag.pubads().setTargeting("bt",o.User.bt),window.localStorage.setItem("bt",o.User.bt);else{a={event:"impression",module:{name:"alice-timing",context:"script-load",label:"alice-error-bt-undefined"}};(window.dataLayer=window.dataLayer||[]).push(a)}if(void 0!==o.User.sub)googletag.pubads().setTargeting("sub",o.User.sub),window.localStorage.setItem("sub",o.User.sub);else{a={event:"impression",module:{name:"alice-timing",context:"script-load",label:"alice-error-sub-undefined"}};(window.dataLayer=window.dataLayer||[]).push(a)}}else{a={event:"impression",module:{name:"alice-timing",context:"script-load",label:"alice-error-user-undefined"}};(window.dataLayer=window.dataL ...
#   }</script><script data-rh="true" id="adslot-config">(function() {
#             var AdSlot4=function(){"use strict";function _(n,i,o){var t=document.getElementsByTagName("head")[0],e=document.createElement("script");i&&(e.onload=i),o&&(e.onerror=o),e.src=n,e.async=!0,t.appendChild(e)}function E(n){var i=document.cookie.match(new RegExp("".concat(n,"=([^;]+)")));return i?i[1]:""}var n={adConfigPosition:5,full:"f",restrictedDataProcessing:"r",nonPersonalized:"n",collapsed:"c",adLuce:"a",socrates:"s"};function S(){return(E("nyt-purr")[n.adConfigPosition]||"")===n.full}var d=[{id:"dfp-ad-top",sizes:{large:[[728,90],[970,90],[970,250]],medium:[[728,90],[300,250]],small:[[300,250],[300,420]]}},{id:"top",sizes:{large:[[728,90],[970,90],[970,250]],medium:[[728,90],[300,250]],small:[[300,250],[300,420]]}}];return function(){var z=window.AdSlot4||{};z.cmd=z.cmd||[];var b=!1;if(z.loadScripts)return z;var o,e=window.innerWidth;function a(t){z.events.subscribe({name:"AdDefined",scope:"all",callback:function(n){var o,i=[-1];n.sizes.forEach(function(n){n[0]<e&&n[0]>i[0]&&(i=[n])}),i[0][1]&&window.apstag.fetchBids({slots:[{slotID:n.truePosition||n.id,slotName:"".concat(n.truePosition||n.id,"_").concat(t,"_web"),sizes:(o=i[0][1],Array.isArray(o)?[[300,250],[728,90],[970,90],[970,250]].filter(function(i){return o.some(function(n){return n[0]===i[0]&&n[1]===i[1]})}):(console.warn("filterSizes() did not receive an array"),[]))}]},function(){window.googletag.cmd.push(function(){window.apstag.setDisplayBids()})})}})}function D(n,i){"art, oak"!==n&&"art,oak"!==n||(n="art"),z.cmd.push(function(){var t,e;i&&window.apstag.fetchBids({slots:(t=o,e=n,d.reduce(function(n,i){var o={slotID:i.id,slotName:"".concat(i,"_").concat(e,"_web"),sizes:i.sizes[t]};return n.push(o),n},[]))},function(){window.googletag.cmd.push(function(){window.apstag.setDisplayBids()})}),a(n)})}return e<=600?o="small":e<=740?o="medium":740<e&&(o="large"),z.loadScripts=function(n){var i,o,t,e,a,d,s,c=n||{},r=c.loadMnet,u=void 0===r||r,l=c.loadAmazon,w=void 0===l||l,p=c.setFastFetch,f=void 0!==p&&p,m=c.loadBait,g=void 0===m||m,v=c.section,h=void 0===v?"none":v,y=c.pageViewId,B=void 0===y?"":y,x=c.pageType,A=void 0===x?"":x;b||("1"!==E("nyt-gdpr")&&(i=document.referrer||"",!((o=/([a-zA-Z0-9_\-.]+)(@|%40)([a-zA-Z0-9_\-.]+).([a-zA-Z]{2,5})/).test(i)||o.test(window.location.href)))&&S()&&(!u||window.advBidxc&&window.advBidxc.isLoaded||(d=B,s="8CU2553YN",window.innerWidth<740&&(s="8CULO58R6"),_("https://contextual.media.net/bidexchange.js?cid=".concat(s,"&dn=").concat("www.nytimes.com","&https=1"),function(){window.advBidxc&&window.advBidxc.isLoaded||console.warn("Media.net not loading properly")},function(){z.cmd.push(function(){z.events.publish({name:"BidderError",value:{type:"Mnet"}})})}),window.advBidxc=window.advBidxc||{},window.advBidxc.renderAd=function(){},window.advBidxc.startTime=(new Date).getTime(),window.advBidxc.customerId={mediaNetCID:s},window.advBidxc.misc={isGptDisabled:1},d&&(window.advBidxc.misc.keywords=d)),w&&!window.apstag&&(t=h,e=A,a=f,function(o,t){function n(n,i){t[o]._Q.push([n,i])}t[o]||(t[o]={init:function(){n("i",arguments)},fetchBids:function(){n("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]})}("apstag",window),_("//c.amazon-adsystem.com/aax2/apstag.js",function(){window.apstag||console.warn("A9 not loading properly")},function(){z.cmd.push(function(){z.events.publish({name:"BidderError",value:{type:"A9"}})})}),window.apstag.init({pubID:"3030",adServer:"googletag",params:{si_section:t}}),D(e,a))),g&&_("https://nytimes.com/ads/google/adsbygoogle.js",function(){},function(){z.cmd.push(function(){z.events.publish({name:"AdEmpty",value:{type:"AdBlockOn"}})})}),b=!0)},window.AdSlot4=z}()}();
#             AdSlot4.loadScripts({
#               loadMnet: window.NYTD.Abra('medianet_home_toggle') !== '1_block',
#               loadAmazon: window.NYTD.Abra('amazon_home_toggle') !== '1_block',
#               setFastFetch: true,
#               section: 'home',
#               pageType: 'hp',
#               pageViewId: window.NYTD.PageViewId.current,
#             });
#             (function () { var _f=function(e){var o=performance.navigation&&1===performance.navigation.type;function n(){return window.matchMedia("(max-width: 739px)").matches}function r(e){var r,i,t,d,a,w,p=function(){var e=window.userXhrObject&&""!==window.userXhrObject.responseText&&JSON.parse(window.userXhrObject.responseText).data||null,o=null;return e&&e.user&&e.user.userInfo&&(o=e.user.userInfo.demographics),o}();return p&&(i=e,d=(r=p)&&r.emailSubscriptions,(a=r&&r.bundleSubscriptions)&&i&&(d&&d.length&&(i.em=d.toString().toLowerCase()),r.wat&&(i.wat=r.wat.toLowerCase()),a&&a.length&&a[0].bundle&&((t=a[0]).source&&(i.subsrc=t.source.toLowerCase()),t.promotion&&(i.subprm=t.promotion),t.in_grace&&(i.grace=t.in_grace.toString()))),e=i),n()?(e.prop="mnyt",e.plat="mweb",e.ver="mvi"):(e.prop="nyt",e.plat="web",e.ver="vi"),"/es/"===window.location.pathname.substring(0,4)&&(e.prop="esnyt",e.edn="es",n()&&(e.prop="mesnyt")),"hp"===e.typ&&(document.referrer&&(e.topref=document.referrer),o&&(e.refresh="manual")),e.abra_dfp=(w=window.NYTD&&window.NYTD.Abra)&&w.config?Object.keys(w.config).reduce(function(e,o){const n=o.toLowerCase(),r=w.getAbraSync&&w.getAbraSync(o)||{};if((n.indexOf("dfp")>-1||o.indexOf("redbird")>-1)&&r.variant){var i=n+"_"+r.variant.toLowerCase();e.push(i)}return e},[]):"",e.page_view_id=window.NYTD.PageViewId&&window.NYTD.PageViewId.current,e.sov=function(){const e=(Math.floor(4*Math.random())+1).toString();return window.sov?window.sov:(window.sov=e,window.sov)}(),e}var i=e||{},t=i.adTargeting||{},d=i.adUnitPath||"/29390238/nyt/homepage",a=i.offset||400,w=i.hideTopAd||n(),p=i.lockdownAds||!1,s=i.sizeMapping||{top:[[970,["fluid",[728,90],[970,90],[970,250],[1605,300]]],[728,["fluid",[728,90],[1605,300]]],[0,[]]],fp1:[[0,[[195,250],[215,270]]]],fp2:[[0,[[195,250],[215,270]]]],fp3:[[0,[[195,250],[215,270]]]],interstitial:[[0,[[1,1],[640,480]]]],mktg:[[1020,[300,250]],[0,[]]],pencil:[[728,[[336,46]],[0,[]]]],pp_edpick:[[0,["fluid"]]],pp_morein:[[0,["fluid"],[210,218]]],ribbon:[[0,["fluid"]]],sponsor:[[765,[150,50]],[0,[320,25]]],supplemental:[[1020,[[300,250],[300,600]]],[0,[]]],chat:[[0,["fluid",[300,250],[300,420]]]],column:[[0,["fluid",[300,250],[300,420]]]],default:[[970,["fluid",[728,90],[970,90],[970,250],[1605,300]]],[728,["fluid",[728,90],[300,250],[1605,300]]],[0,["fluid",[300,250],[300,420]]]]},u=i.dfpToggleName||"dfp_home_toggle",l=i.lazyApi||{};window.AdSlot4=window.AdSlot4||{},window.AdSlot4.cmd=window.AdSlot4.cmd||[],window.AdSlot4.cmd.push(function(){var e,o,n;window.AdSlot4.init({adTargeting:r(t),adUnitPath:d,sizeMapping:s,offset:a,haltDFP:"1_block"===window.NYTD.Abra(u),hideTopAd:w,lockdownAds:p,lazyApi:(e=l,o=e&&e.fetch&&e.render?e:{},n=window.NYTD&&window.NYTD.Abra&&window.NYTD.Abra("dfp_lazy5"),n&&e[n]&&(o=e[n],window.NYTD.Abra.reportExposure("dfp_lazy5")),o)}),window.NYTD.Abra.reportExposure("dfp_adslot4v2")})};;_f.apply(null, [{"adTargeting":{"edn":"us","test":"projectvi","ver":"vi","typ":"hp","vp":"small","als_test":"1585654616540","prop":"mnyt","plat":"mweb","gscat":"neg_mastercard,gs_politics,neg_hearts,neg_ibmtest,gs_entertain,gs_politics_misc,gs_politics_american,gs_science,neg_ibm,gv_death_injury,gs_science_environ,gs_t"},"adUnitPath":null,"dfpToggleName":"dfp_home_toggle"}]); })();
#           })();
#         </script>
# <script type="text/javascript">
#   (function() {
#     /** CONFIGURATION START **/
#     var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#     _sf_async_config.uid = 16698;
#     _sf_async_config.domain = 'nytimes.com';
#     _sf_async_config.flickerControl = false;
#     _sf_async_config.useCanonical = true;
#     _sf_async_config.ignoreQueryParamsEHT = true;
#     /** CONFIGURATION END **/
#   })();
# </script>
# <script async="true" src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
# </head>
# <body>
# <div id="app"><div class="css-rpp6l6 e12j3pa50"><div class="css-ein641 e12j3pa51"><div class="css-142l3g4"><a href="#after-dfp-ad-top" style="position:absolute;width:1px;height:1px;margin:-1px;padding:0;border:0;clip:rect(0 0 0 0);overflow:hidden">Continue reading the main story</a><div class="ad dfp-ad-top-wrapper" style="text-align:center;height:100%;display:block"><div class="place-ad" data-position="top" data-size-key="top" id="dfp-ad-top"></div></div><div id="after-dfp-ad-top"></div></div></div></div><div><div class="NYTAppHideMasthead css-1r6wvpq e1suatyy0"><header class="css-ahe4g0 e1suatyy1"><section class="css-ui9rw0 e1suatyy2"><div class="css-11hrj97 er09x8g0"><div class="css-6n7j50"><button aria-expanded="false" aria-haspopup="true" aria-label="Sections Navigation &amp; Search" class="er09x8g1 css-1uqx5yl" data-testid="nav-button"><svg class="css-1fe7a5q" viewbox="0 0 16 16"><rect fill="#333333" height="2" width="14" x="1" y="3"></rect><rect fill="#333333" height="2" width="14" x="1" y="7"></rect><rect fill="#333333" height="2" width="14" x="1" y="11"></rect></svg></button></div><button aria-label="Sections Navigation" class="css-1o0yzqm er09x8g2" data-testid="desktop-section-button" id="desktop-sections-button"><span class="css-vz7hjd">Sections</span><svg class="css-1fe7a5q" viewbox="0 0 16 16"><rect fill="#333333" height="2" width="14" x="1" y="3"></rect><rect fill="#333333" height="2" width="14" x="1" y="7"></rect><rect fill="#333333" height="2" width="14" x="1" y="11"></rect></svg></button><div class="css-10488qs"><button class="css-fnhm75 ewfai8r0" data-test-id="search-button"><span class="css-vz7hjd">SEARCH</span><svg class="css-1fe7a5q" viewbox="0 0 16 16"><path d="M11.3,9.2C11.7,8.4,12,7.5,12,6.5C12,3.5,9.5,1,6.5,1S1,3.5,1,6.5S3.5,12,6.5,12c1,0,1.9-0.3,2.7-0.7l3.3,3.3c0.3,0.3,0.7,0.4,1.1,0.4s0.8-0.1,1.1-0.4c0.6-0.6,0.6-1.5,0-2.1L11.3,9.2zM6.5,10.3c-2.1,0-3.8-1.7-3.8-3.8c0-2.1,1.7-3.8,3.8-3.8c2.1,0,3.8,1.7,3.8,3.8C10.3,8.6,8.6,10.3,6.5,10.3z" fill="#333"></path></svg></button></div><a class="css-1f8er69" href="#site-content">Skip to content</a><a class="css-1f8er69" href="#site-index">Skip to site index</a></div><div class="css-8xdxq2 e1huz5gh0"><a aria-label="New York Times Logo. Click to visit the homepage" class="css-nhjhh0 e1huz5gh1" data-testid="masthead-mobile-logo" href="/"><svg class="" fill="#000" viewbox="0 0 184 25" xmlns="http://www.w3.org/2000/svg"><path d="M13.8 2.9c0-2-1.9-2.5-3.4-2.5v.3c.9 0 1.6.3 1.6 1 0 .4-.3 1-1.2 1-.7 0-2.2-.4-3.3-.8C6.2 1.4 5 1 4 1 2 1 .6 2.5.6 4.2c0 1.5 1.1 2 1.5 2.2l.1-.2c-.2-.2-.5-.4-.5-1 0-.4.4-1.1 1.4-1.1.9 0 2.1.4 3.7.9 1.4.4 2.9.7 3.7.8v3.1L9 10.2v.1l1.5 1.3v4.3c-.8.5-1.7.6-2.5.6-1.5 0-2.8-.4-3.9-1.6l4.1-2V6l-5 2.2C3.6 6.9 4.7 6 5.8 5.4l-.1-.3c-3 .8-5.7 3.6-5.7 7 0 4 3.3 7 7 7 4 0 6.6-3.2 6.6-6.5h-.2c-.6 1.3-1.5 2.5-2.6 3.1v-4.1l1.6-1.3v-.1l-1.6-1.3V5.8c1.5 0 3-1 3-2.9zm-8.7 11l-1.2.6c-.7-.9-1.1-2.1-1.1-3.8 0-.7 0-1.5.2-2.1l2.1-.9v6.2zm10.6 2.3l-1.3 1 .2.2.6-.5 2.2 2 3-2-.1-.2-.8.5-1-1V9.4l.8-.6 1.7 1.4v6.1c0 3.8-.8 4.4-2.5 5v.3c2.8.1 5.4-.8 5.4-5.7V9.3l.9-.7-.2-.2-.8.6-2.5-2.1L18.5 9V.8h-.2l-3.5 2.4v.2c.4.2 1 .4 1 1.5l-.1 11.3zM34 15.1L31.5 17 29 15v-1.2l4.7-3.2v-.1l-2.4-3.6-5.2 2.8v6.6l-1 .8.2.2.9-.7 3.4 2.5 4.5-3.6-.1-.4zm-5-1.7V8.5l.2-.1 2.2 3.5-2.4 1.5zM53.1 2c0-.3-.1-.6-.2-.9h-.2c-.3.8-.7 1.2-1.7 1.2-.9 0-1.5-.5-1.9-.9l-2.9 3.3.2.2 1-.9c.6.5 1.1.9 2.5 1v8.3L44 3.2c-.5-.8-1.2-1.9-2.6-1.9-1.6 0-3 1.4-2.8 3.6h.3c.1-.6.4-1.3 1.1-1.3.5 0 1 .5 1.3 1v3.3c-1.8 0-3 .8-3 2.3 0 .8.4 2 1.6 2.3v-.2c-.2-.2-.3-.4-.3-.7 0-.5.4-.9 1.1-.9h.5v4.2c-2.1 0-3.8 1.2-3.8 3.2 0 1.9 1.6 2.8 3.4 2.7v-.2c-1.1-.1-1.6-.6-1.6-1.3 0-.9.6-1.3 1.4-1.3.8 0 1.5.5 2 1.1l2.9-3.2-.2-.2-.7.8c-1.1-1-1.7-1.3-3-1.5V5l8 14h.6V5c1.5-.1 2.9-1.3 2.9-3zm7.3 13.1L57.9 17l-2.5-2v-1.2l4.7-3.2v-.1l-2.4-3.6-5.2 2.8v6.6l-1 .8.2.2.9-.7 3.4 2.5 4.5-3.6-.1-.4zm-5-1.7V8.5l.2-.1 2.2 3.5-2.4 1.5zM76.7 8l-.7.5-1.9-1.6-2.2 2 .9.9v7.5l-2.4-1.5V9.6l.8-.5-2.3-2.2-2.2 2 .9.9V17l-.3.2-2.1-1.5v-6c0-1.4-.7-1.8-1.5-2.3-.7-.5-1.1 ...
# <script>window.registerInteractive && window.registerInteractive("100000007024018");</script>
# <!--
#
# ======================================================
#
# THIS IS A GENERATED TEMPLATE FILE. DO NOT EDIT.
#
# ======================================================
#
# -->
# <style type="text/css">
# .story-header.interactive-header {
#
# }
# #g-hp-tabs {
# 	margin: 0 auto;
# 	max-width: 600px;
#
# 	position: relative;
# 	width: 100%;
# }
# @media screen and (max-width: 600px) {
# 	#g-hp-tabs {
# 		padding-bottom: 20px;
# 	}
# }
#
# .g-hp-tabs-inner {
# 	height: 0;
# 	margin: 0;
# 	padding: 0 0 66.66%;
# 	position: relative;
# 	width: 100%;
# }
#
# .g-hp-tab {
# 	background: #fff;
# 	display: none;
# 	height: 100%;
# 	position: absolute;
# 	width: 100%;
# 	z-index: 1;
# }
# .g-hp-tab.g-active {
# 	display: block;
# }
#
# .g-hp-tab .g-media-wrap img,
# .g-hp-tab .g-media-wrap video {
# 	width: 100%;
# }
# .g-hp-tab .g-media-wrap a {
# 	color: inherit;
# 	display: block;
# 	text-decoration: none;
# }
#
# .g-hp-tab .g-media-wrap[data-type="video"] {
# 	background-color: black;
# 	color: white;
# }
#
# .g-hp-tab .g-media-wrap[data-type="video"] p {
# 	color: white;
# 	font-family: nyt-franklin,helvetica,sans-serif;
# 	padding: 20px;
#     font-weight: 700;
#     font-size: 18px;
#     letter-spacing: 0.02em;
# }
#
# @media screen and (max-width: 600px) {
#
# 	.g-hp-tab .g-media-wrap[data-type="video"] p {
# 		font-size: 16px;
# 		padding: 10px;
# 	}
#
# }
#
# .g-hp-tab .g-media-wrap > div {
# 	margin-left: auto;
# 	margin-right: auto;
# 	max-width: none;
#     max-height: none;
# }
# .g-hp-tab h4 {
# 	font-family: nyt-franklin,helvetica,sans-serif;
# 	font-size: 14px;
# 	font-weight: 700;
# 	line-height: 1;
# 	padding-bottom: 10px;
# 	text-transform: uppercase;
# }
# @media screen and (max-width: 600px) {
# 	.g-hp-tab h4 {
# 		display: none;
# 	}
# }
# p.g-hp-cta {
# 	font-family: nyt-franklin,helvetica,sans-serif;
# 	font-size: 12px;
# 	position: absolute;
# 	text-align: center;
# 	bottom :0px;
# 	left: 0;
# 	right: 0;
#
# 	text-decoration: underline;
#
# }
#
# a p.g-hp-cta:hover {
# 	text-decoration: none;
# }
#
#
# p.g-hp-cta:after {
# 	content: '>';
# 	display: inline-block;
# 	background: black;
# 	color: white;
# 	border-radius: 100em;
# 	font-size: 0.75em;
# 	width: 0.75em;
# 	font-weight: bold;
# 	height: 0.75em;
# 	margin-left: 0.5em;
# 	padding: 0.2em 0.35em 0.5em;
# 	line-height: 1.2;
#
# }
#
# @media screen and (min-width: 450px) {
# 	p.g-hp-cta {
# 		font-size: 14px;
#
# 	}
#
# 	p.g-hp-cta:after {
# 		padding: 0.25em 0.35em 0.55em 0.45em;
# 	}
# }
#
# ...
#
#     if (isInApp && isAndroid) document.querySelector('html').classList.add('nytapp-android');
#     if (isInApp && isIos) document.querySelector('html').classList.add('nytapp-ios');
#
#     // NYT apps resize function
#     // Resizes the interactive webview height after a 1 second pause
#     if (window.NYTG && window.NYTG.enqueue) {
#         setTimeout(function() {
#             var container = document.querySelector("#virus-service-nav");
#             var windowWidth = window.innerWidth;
#
#             function resize() {
#                 var height = container.offsetHeight;
#                 window.NYTG.enqueue(
#                     JSON.stringify({ id: 0, type: 'resize', options: { height: height } })
#                 )
#             }
#             window.addEventListener("resize", function() {
#                 if (window.innerWidth != windowWidth) {
#                     windowWidth = window.innerWidth;
#                     resize();
#                 }
#             });
#             resize();
#         }, 1000);
#     }
#
# })();
# </script><!-- Pipeline: 2020-03-09-virus-service | March 30, 2020, 05:56PM | 75323fa03c4c37bab2b6a846dc556ef2126b5bf3 -->
# </div></section></figure></div></div></article></div></div></section></div><div class="css-xc44bh"><section class="css-o3tihn eq74mwp0" data-block-tracking-id="Briefings" data-testid="block-Briefings"><div class="css-avqkzc"><div class="css-a6rejr"><div class="css-1om4z5c"><div class="css-ydsmmq"><article class="css-8atqhb"><div class="css-1ee8y2t assetWrapper"><div class="css-geek62"><div class="css-1d537rb e18972d70" media="[object Object]"><a href="/2020/03/31/podcasts/the-daily/coronavirus-medical-supplies-shortages.html"><div class="css-1g8bx4t"><figure class="css-mky99g"><img alt="" src="https://static01.nyt.com/images/2017/01/29/podcasts/the-daily-album-art/the-daily-album-art-square320-v4.png"/></figure></div></a></div><a href="/2020/03/31/podcasts/the-daily/coronavirus-medical-supplies-shortages.html"><div class="css-8oysku e18972d71" type="1"><div class="css-1064d4e esl82me1"><h2 class="css-nhfrhl esl82me0">Listen to ‘The Daily’</h2></div></div><div class="css-8oysku e18972d71"><p class="css-gs67ux e1n8kpyg0">Why the U.S. is running out of medical supplies. </p></div></a></div></div></article></div><div class="css-ydsmmq"><article class="css-8atqhb"><div class="css-1ee8y2t assetWrapper"><div class="css-geek62"><div class="css-1d537rb e18972d70" media="[object Object]"><a href="/2020/03/26/podcasts/still-processing-quarantine.html"><div class="css-1g8bx4t"><figure class="css-mky99g"><img alt="" src="https://static01.nyt.com/images/2019/09/15/podcasts/still-processing-album-art-2/still-processing-album-art-2-square320.jpg"/></figure></div></a></div><a href="/2020/03/26/podcasts/still-processing-quarantine.html"><div class="css-8oysku e18972d71" type="1"><div class="css-1064d4e esl82me1"><h2 class="css-nhfrhl esl82me0">Listen to ‘Still Processing’</h2></div></div><div class="css-8oysku e18972d71"><p class="css-gs67ux e1n8kpyg0">A new season for a new time.</p></div></a></div></div></article></div><div class="css-ydsmmq"><article class="css-8atqhb"><div class="css-1ee8y2t assetWrapper"><div class="css-geek62"><div class="css-1d537rb e18972d70" media="[object Object]"><a href="/2020/03/25/style/modern-love-podcast-uzo-aduba.html"><div class="css-1g8bx4t"><figure class="css-mky99g"><img alt="" src="https://static01.nyt.com/images/2019/04/04/style/00MODERNLOVEPODCAST-ART/00MODERNLOVEPODCAST-ART-square320.png"/></figure></div></a></div><a href="/2020/03/25/style/modern-love-podcast-uzo-aduba.html"><div class="css-8oysku e18972d71" type="1"><div class="css-1064d4e esl82me1"><h2 class="css-nhfrhl esl82me0">Listen: ‘Modern Love’ Podcast</h2></div></div><div class="css-8oysku e18972d71"><p class="css-gs67ux e1n8kpyg0">What’s a book lover’s most embarrassing secret?</p></div></a></div></div></article></div></div><div class="css-1y8l3jc"><div class="css-7utnqv"><div class="css-rlo25n e1ll57lj2"></div></div><div class="css-1hesgbm"></div></div></div></div></section></div></div><div class="css-698um9"><div class="css-1tk5puc"><div class="css-jbmajz"><div class="css-na8bie"><section class="css-15zaaaz eq74mwp0" data-block-tracking-id="Top Stories" data-testid="block-TopStories"><div class="css-1goe63e e1aa0s8g0"><div class="css-10zwa5e eqveam64"><h3>U.S.</h3></div><div class="css-1qiat4j eqveam63"><div class="css-1yoguk1 eqveam60"><div class="css-1qj0wac eqveam61"><article class="css-8atqhb"><div class="css-1ee8y2t assetWrapper"><div class="css-6p6lnl"><a href="/2020/03/30/us/coronavirus-funeral-albany-georgia.html"><div class="css-1ez5fsm esl82me1"><h2 class="css-1vvhd4r esl82me0"><span>Days After a Funeral, Virus ‘Hit Like a Bomb’</span></h2></div><p class="css-1pfq5u e1n8kpyg0">Mourners gathered to share the loss of a loved one in the town of Albany, Ga. In the weeks that followed, illness tore through the community.</p></a><div class="css-1slnf6i"><div class="css-na047m"><span class="css-ud8usf e1c8ga110"></span><div class="css-16f7co2"></div></div></div></div></div></article></div></div><div class="css-1mnngwr eqveam60"><div cla ...
# <script>window.__preloadedData = {"initialState":{"Program_Beta:UHJvZ3JhbV9CZXRhOmhvbWUtbGFyZ2U=":{"id":"UHJvZ3JhbV9CZXRhOmhvbWUtbGFyZ2U=","spotlightA":{"type":"id","generated":false,"id":"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0","typename":"Block_Beta"},"spotlightB":{"type":"id","generated":false,"id":"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL3Nwb3RsaWdodA==","typename":"Block_Beta"},"topPrimaryA":{"type":"id","generated":false,"id":"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL3RvcHN0b3JpZXM=","typename":"Block_Beta"},"topSecondaryA":{"type":"id","generated":false,"id":"MultiListBlock_Beta:TXVsdGlMaXN0QmxvY2tfQmV0YTpob21lLWxhcmdlL2JyaWVmaW5n","typename":"MultiListBlock_Beta"},"topSecondaryB":{"type":"id","generated":false,"id":"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL29waW5pb24=","typename":"Block_Beta"},"topSecondaryC":{"type":"id","generated":false,"id":"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2VkaXRvcnNwaWNrcw==","typename":"Block_Beta"},"adTargetingParams({\"clientAdParams\":{\"edn\":\"us\",\"plat\":\"web\",\"prop\":\"nyt\"}})":[{"type":"id","generated":false,"id":"AdTargetingParam:als_test1585654616540","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:propnyt","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:platweb","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:ednus","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:typ","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:pt","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:gscatneg_mastercard,gs_politics,neg_hearts,neg_ibmtest,gs_entertain,gs_politics_misc,gs_politics_american,gs_science,neg_ibm,gv_death_injury,gs_science_environ,gs_t","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:tt","typename":"AdTargetingParam"},{"type":"id","generated":false,"id":"AdTargetingParam:mt","typename":"AdTargetingParam"}],"__typename":"Program_Beta"},"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0":{"id":"QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0","firstLoad":{"type":"id","generated":true,"id":"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0.firstLoad","typename":"AssetsConnection"},"__typename":"Block_Beta","title":"Alert","showSection":false,"dataId":"home-large\u002Falert","dataSource":"nyt:\u002Flist\u002Fscoop\u002Flist\u002Fhome-alert","firstLoad({\"first\":1000})":{"type":"id","generated":true,"id":"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0.firstLoad({\"first\":1000})","typename":"AssetsConnection"}},"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0.firstLoad":{"totalCount":0,"__typename":"AssetsConnection"},"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL2FsZXJ0.firstLoad({\"first\":1000})":{"edges@take({\"first\":1000})":[],"totalCount":0,"__typename":"AssetsConnection"},"Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL3Nwb3RsaWdodA==":{"id":"QmxvY2tfQmV0YTpob21lLWxhcmdlL3Nwb3RsaWdodA==","firstLoad":{"type":"id","generated":true,"id":"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL3Nwb3RsaWdodA==.firstLoad","typename":"AssetsConnection"},"__typename":"Block_Beta","title":"Spotlight","showSection":false,"dataId":"home-large\u002Fspotlight","dataSource":"nyt:\u002Flist\u002Fscoop\u002Flist\u002Fhome-breaking","firstLoad({\"first\":1000})":{"type":"id","generated":true,"id":"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL3Nwb3RsaWdodA==.firstLoad({\"first\":1000})","typename":"AssetsConnection"}},"$Block_Beta:QmxvY2tfQmV0YTpob21lLWxhcmdlL3Nwb3RsaWdodA==.firstLoad":{"totalCount":3,"__typename":"AssetsConnection"},"Package:UGFja2FnZTpueXQ6Ly9wYWNrYWdlLzIyODM0ZjczLWQ1ZjEtNTg4Ny1iNDQzLTYwMzljODZmZjM3OA==":{"id":"UGFja2FnZTpueXQ6Ly9wYWNrYWdlLzIyODM0ZjczLWQ1ZjEtNTg4Ny1iNDQzLTYwMzljODZmZjM3OA==","__typename":"Package","promotionalSummary":"","promotionalBullets":{"type":"json","json":[]},"promotionalHeadline":"","newsStatus":"LIVE","oneLine":"","banner":"", ...
# <script>!function(e){function r(r){for(var d,c,n=r[0],s=r[1],i=r[2],f=0,l=[];f<n.length;f++)c=n[f],Object.prototype.hasOwnProperty.call(t,c)&&t[c]&&l.push(t[c][0]),t[c]=0;for(d in s)Object.prototype.hasOwnProperty.call(s,d)&&(e[d]=s[d]);for(b&&b(r);l.length;)l.shift()();return o.push.apply(o,i||[]),a()}function a(){for(var e,r=0;r<o.length;r++){for(var a=o[r],d=!0,n=1;n<a.length;n++){var s=a[n];0!==t[s]&&(d=!1)}d&&(o.splice(r--,1),e=c(c.s=a[0]))}return e}var d={},t={52:0},o=[];function c(r){if(d[r])return d[r].exports;var a=d[r]={i:r,l:!1,exports:{}};return e[r].call(a.exports,a,a.exports,c),a.l=!0,a.exports}c.e=function(e){var r=[],a=t[e];if(0!==a)if(a)r.push(a[2]);else{var d=new Promise((function(r,d){a=t[e]=[r,d]}));r.push(a[2]=d);var o,n=document.createElement("script");n.charset="utf-8",n.timeout=120,c.nc&&n.setAttribute("nonce",c.nc),n.src=function(e){return c.p+""+({1:"vendors~audio~byline~capsule~cityguides~collections~home~liveblog~paidpost~slideshow~story~video",2:"answerpage~bestsellers~hubpage~reviews~search~slideshow~timeswire~trending~weddings~your-list",3:"vendors~audio~capsule~cityguides~collections~home~liveblog~paidpost~story~trending~video",4:"vendors~audio~capsule~cityguides~collections~home~liveblog~paidpost~story~video",5:"answerpage~bestsellers~byline~hubpage~reviews~search~trending~your-list",6:"bestsellers~byline~reviews",7:"embededGetStarted~getstarted~readInAppPrompt",8:"vendors~newsletter~newsletters~weekender",9:"answerpage~hubpage",10:"embededGetStarted~getstarted",11:"newsletter~newsletters",12:"recirculation~weekender",13:"vendors~commentsForm~weddings",14:"additionalPlaylists",16:"answerpage",17:"audio",18:"audioblock",19:"bestsellers",20:"blank",21:"byline",22:"capsule",23:"cityguides",24:"coderedeem",25:"collections",26:"comments",27:"commentsForm",28:"desktopNav",29:"embededGetStarted",30:"episodefooter",31:"footerBlock",32:"getstarted",33:"home",34:"hubpage",36:"liveblog",38:"newsletter",39:"newsletters",40:"paidpost",41:"phone-number-input",42:"privacy",43:"programmables",44:"readInAppPrompt",45:"recirculation",46:"refer",47:"regilite",48:"related-coverage-chunk",49:"reviews",53:"search",54:"
>
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P528B3&gt;m_auth=tfAzqo1rYDLgYhmTnSjPqw&gt;m_preview=env-130&gt;m_cookies_win=x" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <div id="RavenInstaller">
# <script>
# if (window.INSTALL_RAVEN) {
#   function installRaven() {
#     /* eslint-disable */
# // Install Raven
# window.Raven
#   .config('https://7bc8bccf5c254286a99b11c68f6bf4ce@sentry.io/178860', {
#     release: vi.env.RELEASE,
#     environment: vi.env.ENVIRONMENT,
#     ignoreErrors: [/SecurityError: Blocked a frame with origin.*/],
#   })
#   .install();
#
# // Stop using our error handler
# window.nyt_errors.ravenInstalled = true;
# var regex = /nyt-a=(.*?)(;|$)/;
# var id = regex.exec(document.cookie);
#
# if (id !== null) {
#   id = id[1];
# } else {
#   id = '';
# }
#
# // Setting nyt-a as user context
# window.Raven.setUserContext({
#   id: id,
# });
#
# // Pass collected errors to Raven
# var nytErrorsList = window.nyt_errors.list;
# var nytErrorsTags = window.nyt_errors.tags;
#
# for (var i = 0; i < nytErrorsList.length; i += 1) {
#   var err = nytErrorsList[i];
#   // weird?
#   if (!err) { continue; }
#
#   // also weird ... ?
#   if (!err.err) {
#     // maybe err itself is an Error?
#     if (err instanceof Error) {
#       window.Raven.captureException(err, err.data || {});
#     } // else { silently ignore? }
#   }
#
#   // just making sure ...
#   if (err.err instanceof Error) {
#     window.Raven.captureException(err.err, err.data || {});
#   } // else { silently ignore? }
# }
#
# // Pass collected Tags to Raven
# for (var i = 0; i < nytErrorsTags.length; i += 1) {
#   window.Raven.setTagsContext(nytErrorsTags[i]);
# }
#
#   }
#   window.addEventListener('load', function(event) {
#     if (!window.Raven) {
#       var includeRaven = document.getElementById("RavenInstaller");
#       var script = document.createElement("script");
#       script.src = "/vi-assets/static-assets/raven.min-830a6d04a55c283934dd1893d6ddc66d.js";
#       script.onload = function() {
#         installRaven();
#       };
#       includeRaven.appendChild(script);
#     } else {
#       installRaven();
#     }
#   });
# }
# </script>
# </div>
# <!-- RELEASE 702c9269ea45b6708427fed796218cefe33d93e2 -->
# </body>
# </html>

# %%
print(bsoup.title.text)
# Out:
# The New York Times - Breaking News, World News & Multimedia

# %%
for link in bsoup.find_all('a'):
    print(link.get('href'))
# Out:
# #after-dfp-ad-top
# #site-content
# #site-index
# /
# /
# https://www.nytimes.com/es/
# https://cn.nytimes.com
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi
# https://myaccount.nytimes.com/auth/login?response_type=cookie&client_id=vi
# https://www.nytimes.com/section/todayspaper
# /
# /
# https://www.nytimes.com/section/world
# https://www.nytimes.com/section/us
# https://www.nytimes.com/section/politics
# https://www.nytimes.com/section/nyregion
# https://www.nytimes.com/section/business
# https://www.nytimes.com/section/opinion
# https://www.nytimes.com/section/technology
# https://www.nytimes.com/section/science
# https://www.nytimes.com/section/health
# https://www.nytimes.com/section/sports
# https://www.nytimes.com/section/arts
# https://www.nytimes.com/section/books
# https://www.nytimes.com/section/style
# https://www.nytimes.com/section/food
# https://www.nytimes.com/section/travel
# https://www.nytimes.com/section/magazine
# https://www.nytimes.com/section/t-magazine
# https://www.nytimes.com/section/realestate
# https://www.nytimes.com/video
# https://www.nytimes.com/section/world
# https://www.nytimes.com/section/us
# https://www.nytimes.com/section/politics
# https://www.nytimes.com/section/nyregion
# https://www.nytimes.com/section/business
# https://www.nytimes.com/section/opinion
# https://www.nytimes.com/section/technology
# https://www.nytimes.com/section/science
# https://www.nytimes.com/section/health
# https://www.nytimes.com/section/sports
# https://www.nytimes.com/section/arts
# https://www.nytimes.com/section/books
# https://www.nytimes.com/section/style
# https://www.nytimes.com/section/food
# https://www.nytimes.com/section/travel
# https://www.nytimes.com/section/magazine
# https://www.nytimes.com/section/t-magazine
# https://www.nytimes.com/section/realestate
# https://www.nytimes.com/video
# /2020/03/31/world/coronavirus-news.html
# /2020/03/31/world/coronavirus-news.html
# https://www.nytimes.com/interactive/2020/world/coronavirus-maps.html?action=click&module=Top%20Stories&pgtype=Homepage
# https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html
# https://www.nytimes.com/2020/03/31/business/stock-market-today-coronavirus.html
# /2020/03/30/us/politics/trump-governors-coronavirus-testing.html
# /2020/03/31/business/stock-market-today-coronavirus.html
# /2020/03/30/us/politics/trump-coronavirus.html
# /2020/03/30/us/politics/trump-coronavirus.html
# /2020/03/30/us/politics/trump-coronavirus.html#commentsContainer
# /2020/03/30/us/politics/trump-women-coronavirus.html
# /2020/03/30/us/politics/trump-women-coronavirus.html
# /2020/03/30/us/politics/trump-women-coronavirus.html#commentsContainer
://help.nytimes.com/hc/en-us/articles/115014893428-Terms-of-service
# https://help.nytimes.com/hc/en-us/articles/115014893968-Terms-of-sale
# https://spiderbites.nytimes.com
# https://help.nytimes.com/hc/en-us
# https://www.nytimes.com/subscription?campaignId=37WXW

# %%
print(bsoup.p)
# Out:
# <p class="g-hp-cta">See more maps</p>

# %%
print(bsoup.find_all('p'))
# Out:
# [<p class="g-hp-cta">See more maps</p>, <p class="g-hp-cta">See more maps</p>, <p class="g-index-name">S&amp;P 500 <span class="g-name-dek">U.S.</span></p>, <p class="g-sp-value"></p>, <p class="g-sp-change">%</p>, <p class="g-index-name">Dow <span class="g-name-dek">U.S.</span></p>, <p class="g-dow-value"></p>, <p class="g-dow-change">%</p>, <p class="g-index-name">Oil <span class="g-name-dek">W.T.I.</span></p>, <p class="g-oil-value"></p>, <p class="g-oil-change">%</p>, <p class="g-index-name">Nikkei <span class="g-name-dek">Japan</span></p>, <p class="g-nikkei-value"></p>, <p class="g-nikkei-change">%</p>, <p class="g-index-name">Dax <span class="g-name-dek">Germany</span></p>, <p class="g-dax-value"></p>, <p class="g-dax-change">%</p>, <p class="g-index-name">FTSE <span class="g-name-dek">Britain</span></p>, <p class="g-ftse-value"></p>, <p class="g-ftse-change">%</p>, <p class="g-change-label">Daily change</p>, <p class="g-updated-timestamp-text">Data delayed at least 15 minutes
#             <!--span id="g-last-updated-value"></span-->
# </p>, <p>Spain's ‘Health Care Kamikazes’ Battle Coronavirus</p>, <p class="css-1pfq5u e1n8kpyg0">The president said on a conference call that he had not “heard about testing in weeks.”</p>, <p class="css-1pfq5u e1n8kpyg0">Global stock markets showed cautious optimism, predicting a modest rise on Wall Street.</p>, <p class="css-1pfq5u e1n8kpyg0">Polling numbers and a threat of mass casualties changed, for now, the president’s approach to the coronavirus pandemic.</p>, <p class="css-1pfq5u e1n8kpyg0">Now part of the long list of women the president has insulted: a governor, a reporter, the head of General Motors and, of course, the House speaker.</p>, <p class="css-gs67ux e1n8kpyg0">Why the U.S. is running out of medical supplies. </p>, <p class="css-gs67ux e1n8kpyg0">A new season for a new time.</p>, <p class="css-gs67ux e1n8kpyg0">What’s a book lover’s most embarrassing secret?</p>, <p class="css-1pfq5u e1n8kpyg0">Mourners gathered to share the loss of a loved one in the town of Albany, Ga. In the weeks that followed, illness tore through the community.</p>, <p class="css-1pfq5u e1n8kpyg0">Instacart and Amazon are the latest targets of labor action by groups fearing coronavirus exposure on the job.</p>, <p class="css-1pfq5u e1n8kpyg0">Leaders around the world have passed emergency decrees and legislation expanding their reach. Will they ever rescind them?</p>, <p class="css-1pfq5u e1n8kpyg0">Joe Biden’s campaign and top donors are racing to reimagine the ways they raise money as worries grow that the coronavirus could choke off contributions from donors big and small.</p>, <p class="css-1pfq5u e1n8kpyg0">For decades, the writer Gabriel Matzneff used Francesca Gee’s image and letters to champion his sexual pursuit of adolescents. But her own account was rejected, until now.</p>, <p class="css-1pfq5u e1n8kpyg0">Governor Cuomo and state lawmakers should pass a streamlined budget and fight their policy battles another day.</p>, <p class="css-1pfq5u e1n8kpyg0">Here’s how to do it.</p>, <p class="css-1pfq5u e1n8kpyg0">Confined to their homes, Americans are kneading dough.</p>, <p class="css-1pfq5u e1n8kpyg0">Adam Koszary turned a tiny agricultural museum into a social media sensation. What can the world’s major institutions learn from him?</p>, <p class="css-1pfq5u e1n8kpyg0">The novelist Ann Patchett didn’t read middle-grade books. Then she picked up one by Kate DiCamillo and couldn’t stop until she’d read them all.</p>, <p class="css-1qo9wc0">We’d like your thoughts on the New York Times home page experience.<a href="http://nyt.qualtrics.com/jfe/form/SV_eFJmKj9v0krSE0l" rel="noopener noreferrer" target="_blank">Let us know what you think</a><svg height="11" viewbox="0 0 7 12" width="7"><path d="M1 1l4.333 5L1 11" fill="none" fill-rule="evenodd" stroke="#fff" stroke-width="2"></path></svg></p>]

# %%
print(bsoup.find('p').get_text())
# Out:
# See more maps

# %%
ptags = bsoup.find_all('p')
for p in ptags:
    print(p.text)
    print(" ")
# Out:
# See more maps
#
# See more maps
#
# S&P 500 U.S.
#
#
#
# %
#
# Dow U.S.
#
#
#
# %
#
# Oil W.T.I.
#
#
#
# %
#
# Nikkei Japan
#
#
#
# %
#
# Dax Germany
#
#
#
# %
#
# FTSE Britain
#
#
#
# %
#
# Daily change
#
# Data delayed at least 15 minutes
#
#
#
# Spain's ‘Health Care Kamikazes’ Battle Coronavirus
#
# The president said on a conference call that he had not “heard about testing in weeks.”
#
# Global stock markets showed cautious optimism, predicting a modest rise on Wall Street.
#
# Polling numbers and a threat of mass casualties changed, for now, the president’s approach to the coronavirus pandemic.
#
# Now part of the long list of women the president has insulted: a governor, a reporter, the head of General Motors and, of course, the House speaker.
#
# Why the U.S. is running out of medical supplies.
#
# A new season for a new time.
#
# What’s a book lover’s most embarrassing secret?
#
# Mourners gathered to share the loss of a loved one in the town of Albany, Ga. In the weeks that followed, illness tore through the community.
#
# Instacart and Amazon are the latest targets of labor action by groups fearing coronavirus exposure on the job.
#
# Leaders around the world have passed emergency decrees and legislation expanding their reach. Will they ever rescind them?
#
# Joe Biden’s campaign and top donors are racing to reimagine the ways they raise money as worries grow that the coronavirus could choke off contributions from donors big and small.
#
# For decades, the writer Gabriel Matzneff used Francesca Gee’s image and letters to champion his sexual pursuit of adolescents. But her own account was rejected, until now.
#
# Governor Cuomo and state lawmakers should pass a streamlined budget and fight their policy battles another day.
#
# Here’s how to do it.
#
# Confined to their homes, Americans are kneading dough.
#
# Adam Koszary turned a tiny agricultural museum into a social media sensation. What can the world’s major institutions learn from him?
#
# The novelist Ann Patchett didn’t read middle-grade books. Then she picked up one by Kate DiCamillo and couldn’t stop until she’d read them all.
#
# We’d like your thoughts on the New York Times home page experience.Let us know what you think

# %%
src = urllib.request.urlopen('http://www.espn.com/nba/statistics/player/_/stat/assists/sort/avgAssists/').read()
bsoup = bs.BeautifulSoup(src)
tbl = bsoup.find('table')

# %%
tbl_rows = tbl.find_all('tr')
for tr in tbl_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['1', 'James HardenHOU']
# ['2', 'Bradley BealWSH']
# ['3', 'Giannis AntetokounmpoMIL']
# ['4', 'Trae YoungATL']
# ['5', 'Damian LillardPOR']
# ['6', 'Luka DoncicDAL']
# ['7', 'Russell WestbrookHOU']
# ['8', 'Kawhi LeonardLAC']
# ['9', 'Anthony DavisLAL']
# ['10', 'Devin BookerPHX']
# ['11', 'LeBron JamesLAL']
# ['12', 'Zach LaVineCHI']
# ['13', 'Brandon IngramNO']
# ['14', 'Donovan MitchellUTAH']
# ['15', 'Pascal SiakamTOR']
# ['16', 'Jayson TatumBOS']
# ['17', 'CJ McCollumPOR']
# ['18', 'DeMar DeRozanSA']
# ['19', 'Andrew WigginsGS/MIN']
# ['20', 'Kemba WalkerBOS']
# ['21', 'Khris MiddletonMIL']
# ['22', 'Collin SextonCLE']
# ['23', 'Spencer DinwiddieBKN']
# ['24', "De'Aaron FoxSAC"]
# ['25', 'Jaylen BrownBOS']
# ['26', 'Jimmy ButlerMIA']
# ['27', 'Bojan BogdanovicUTAH']
# ['28', 'Nikola JokicDEN']
# ['29', 'Buddy HieldSAC']
# ['30', 'Kyle LowryTOR']
# ['31', 'Jrue HolidayNO']
# ['32', 'Julius RandleNY']
# ['33', 'Nikola VucevicORL']
# ['34', 'Tobias HarrisPHI']
# ['35', 'Shai Gilgeous-AlexanderOKC']
# ['36', 'Kristaps PorzingisDAL']
# ['37', 'Danilo GallinariOKC']
# ['38', 'Dennis SchroderOKC']
# ['39', 'LaMarcus AldridgeSA']
# ['40', 'Evan FournierORL']
# ['41', 'Jamal MurrayDEN']
# ['42', 'T.J. WarrenIND']
# ['43', 'Kelly Oubre Jr.PHX']
# ['44', 'Lou WilliamsLAC']
# ['45', 'Montrezl HarrellLAC']
# ['46', 'Domantas SabonisIND']
# ['47', "Devonte' GrahamCHA"]
# ['48', 'Derrick RoseDET']
# ['49', 'Terry RozierCHA']
# ['50', 'Andre DrummondCLE/DET']

# %%
type(row)
# Out:
# list

# %%
import pandas as pd 
data = pd.read_html("http://www.espn.com/nba/statistics/player/_/stat/assists/sort/avgAssists/")
for df in data:
    print(df)
# Out:
#     RK                        Name
# 0    1             James HardenHOU
# 1    2             Bradley BealWSH
# 2    3    Giannis AntetokounmpoMIL
# 3    4               Trae YoungATL
# 4    5           Damian LillardPOR
# 5    6              Luka DoncicDAL
# 6    7        Russell WestbrookHOU
# 7    8            Kawhi LeonardLAC
# 8    9            Anthony DavisLAL
# 9   10             Devin BookerPHX
# 10  11             LeBron JamesLAL
# 11  12              Zach LaVineCHI
# 12  13            Brandon IngramNO
# 13  14        Donovan MitchellUTAH
# 14  15            Pascal SiakamTOR
# 15  16             Jayson TatumBOS
# 16  17              CJ McCollumPOR
# 17  18             DeMar DeRozanSA
# 18  19        Andrew WigginsGS/MIN
# 19  20             Kemba WalkerBOS
# 20  21          Khris MiddletonMIL
# 21  22            Collin SextonCLE
# 22  23        Spencer DinwiddieBKN
# 23  24             De'Aaron FoxSAC
# 24  25             Jaylen BrownBOS
# 25  26             Jimmy ButlerMIA
# 26  27        Bojan BogdanovicUTAH
# 27  28             Nikola JokicDEN
# 28  29              Buddy HieldSAC
# 29  30               Kyle LowryTOR
